# %%
## 数据导入
import pandas as pd
import numpy as np

train = pd.read_csv(r'D:\NUSMaster\semester1\CS5344BigDataAnalytic\Projects\sample_processes_train.csv')  # 读取csv文件

# %%
train.info()  # 查看数据基本信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127744 entries, 0 to 127743
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   index            127744 non-null  int64
#  1   target           127744 non-null  int64
#  2   timestamp        127744 non-null  float64
#  3   processId        127744 non-null  int64
#  4   threadId         127744 non-null  int64
#  5   parentProcessId  127744 non-null  int64
#  6   userId           127744 non-null  int64
#  7   mountNamespace   127744 non-null  int64
#  8   processName      127744 non-null  object
#  9   hostName         127744 non-null  int64
#  10  eventId          127744 non-null  int64
#  11  eventName        127744 non-null  object
#  12  stackAddresses   127744 non-null  object
#  13  argsNum          127744 non-null  int64
#  14  returnValue      127744 non-null  int64
#  15  args             127744 non-null  object
# dtypes: float64(1), int64(11), object(4)
# memory usage: 15.6+ MB

# %%
## 特征工程（涉及 缺失数据， 数据编码， 异常数据处理etc）

# %%
### missing data imputation 
### using feature-engine
from sklearn.impute import SimpleImputer

# 查看缺失值
train.isnull().sum()
# Out:
# index              0
# target             0
# timestamp          0
# processId          0
# threadId           0
# parentProcessId    0
# userId             0
# mountNamespace     0
# processName        0
# hostName           0
# eventId            0
# eventName          0
# stackAddresses     0
# argsNum            0
# returnValue        0
# args               0
# dtype: int64

# %%
train['args'][0] ## Python 的 list of dicts（字符串形式）
# Out:
# "[{'name': 'domain', 'type': 'int', 'value': 'AF_UNIX'}, {'name': 'type', 'type': 'int', 'value': 'SOCK_DGRAM|SOCK_CLOEXEC'}, {'name': 'protocol', 'type': 'int', 'value': 0}]"

# %%
import ast
import pandas as pd

# 假设 train 已经有 args 列
train['args_parsed'] = train['args'].apply(ast.literal_eval)

# %%
# 转换成 {name: value} 的字典
def list_to_dict(lst):
    return {d['name']: d['value'] for d in lst}

train['args_dict'] = train['args_parsed'].apply(list_to_dict)

# 展开成 DataFrame
args_df = pd.json_normalize(train['args_dict'])

# %%
args_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127744 entries, 0 to 127743
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   domain      451 non-null    object
#  1   type        451 non-null    object
#  2   protocol    451 non-null    float64
#  3   pathname    65560 non-null  object
#  4   flags       51280 non-null  object
#  5   dev         14324 non-null  float64
#  6   inode       14324 non-null  float64
#  7   fd          57149 non-null  float64
#  8   statbuf     26285 non-null  object
#  9   dirfd       36772 non-null  float64
#  10  mode        43398 non-null  object
#  11  ruid        4 non-null      float64
#  12  euid        4 non-null      float64
#  13  rgid        11 non-null     float64
#  14  egid        11 non-null     float64
#  15  cap         2832 non-null   object
#  16  sockfd      591 non-null    float64
#  17  addr        591 non-null    object
#  18  addrlen     591 non-null    object
#  19  dirp        785 non-null    object
#  20  count       785 non-null    float64
#  21  stack       192 non-null    object
#  22  parent_tid  192 non-null    object
#  23  child_tid   192 non-null    object
#  24  tls         192 non-null    float64
#  25  option      411 non-null    object
#  26  arg2        411 non-null    float64
#  27  arg3        411 non-null    float64
#  28  arg4        411 non-null    float64
#  29  arg5        411 non-null    float64
#  30  pid         192 non-null    float64
#  31  sig         192 non-null    float64
#  32  target      1 non-null      object
#  33  oldfd       143 non-null    float64
#  34  newfd       132 non-null    float64
#  35  uid         7 non-null      float64
#  36  argv        36 non-null     object
#  37  gid         3 non-null      float64
# dtypes: float64(22), object(16)
# memory usage: 37.0+ MB

# %%
train = pd.concat([train.drop(columns=['args', 'args_parsed', 'args_dict']), args_df], axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127744 entries, 0 to 127743
# Data columns (total 53 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   index            127744 non-null  int64
#  1   target           127744 non-null  int64
#  2   timestamp        127744 non-null  float64
#  3   processId        127744 non-null  int64
#  4   threadId         127744 non-null  int64
#  5   parentProcessId  127744 non-null  int64
#  6   userId           127744 non-null  int64
#  7   mountNamespace   127744 non-null  int64
#  8   processName      127744 non-null  object
#  9   hostName         127744 non-null  int64
#  10  eventId          127744 non-null  int64
#  11  eventName        127744 non-null  object
#  12  stackAddresses   127744 non-null  object
#  13  argsNum          127744 non-null  int64
#  14  returnValue      127744 non-null  int64
#  15  domain           451 non-null     object
#  16  type             451 non-null     object
#  17  protocol         451 non-null     float64
#  18  pathname         65560 non-null   object
#  19  flags            51280 non-null   object
#  20  dev              14324 non-null   float64
#  21  inode            14324 non-null   float64
#  22  fd               57149 non-null   float64
#  23  statbuf          26285 non-null   object
#  24  dirfd            36772 non-null   float64
#  25  mode             43398 non-null   object
#  26  ruid             4 non-null       float64
#  27  euid             4 non-null       float64
#  28  rgid             11 non-null      float64
#  29  egid             11 non-null      float64
#  30  cap              2832 non-null    object
#  31  sockfd           591 non-null     float64
#  32  addr             591 non-null     object
#  33  addrlen          591 non-null     object
#  34  dirp             785 non-null     object
#  35  count            785 non-null     float64
#  36  stack            192 non-null     object
#  37  parent_tid       192 non-null     object
#  38  child_tid        192 non-null     object
#  39  tls              192 non-null     float64
#  40  option           411 non-null     object
#  41  arg2             411 non-null     float64
#  42  arg3             411 non-null     float64
#  43  arg4             411 non-null     float64
#  44  arg5             411 non-null     float64
#  45  pid              192 non-null     float64
#  46  sig              192 non-null     float64
#  47  target           1 non-null       object
#  48  oldfd            143 non-null     float64
#  49  newfd            132 non-null     float64
#  50  uid              7 non-null       float64
#  51  argv             36 non-null      object
#  52  gid              3 non-null       float64
# dtypes: float64(23), int64(11), object(19)
# memory usage: 51.7+ MB

# %%
train.isnull().sum()
# Out:
# index                   0
# target                  0
# timestamp               0
# processId               0
# threadId                0
# parentProcessId         0
# userId                  0
# mountNamespace          0
# processName             0
# hostName                0
# eventId                 0
# eventName               0
# stackAddresses          0
# argsNum                 0
# returnValue             0
# domain             127293
# type               127293
# protocol           127293
# pathname            62184
# flags               76464
# dev                113420
# inode              113420
# fd                  70595
# statbuf            101459
# dirfd               90972
# mode                84346
# ruid               127740
# euid               127740
# rgid               127733
# egid               127733
# cap                124912
# sockfd             127153
# addr               127153
# addrlen            127153
# dirp               126959
# count              126959
# stack              127552
# parent_tid         127552
# child_tid          127552
# tls                127552
# option             127333
# arg2               127333
# arg3               127333
# arg4               127333
# arg5               127333
# pid                127552
# sig                127552
# target             127743
# oldfd              127601
# newfd              127612
# uid                127737
# argv               127708
# gid                127741
# dtype: int64

# %%
train.size
# Out:
# 6770432

# %%
# 5. 导出成新的 CSV
train.to_csv("D:/NUSMaster/semester1/CS5344BigDataAnalytic/Projects/sample_processes_train_parsed.csv", index=False)

print("✅ 已经生成新的 CSV 文件: sample_processes_train_parsed.csv")
# Out:
# ✅ 已经生成新的 CSV 文件: sample_processes_train_parsed.csv

# %%
# 查看当前train中的数值型特征是否有缺失值
# 只选择数值型列
num_cols = train.select_dtypes(include=['int64', 'float64']).columns
# 统计每个数值型列的缺失值个数
missing_numeric = train[num_cols].isnull().sum()
# 只显示有缺失的列
missing_numeric = missing_numeric[missing_numeric > 0]
print(missing_numeric)
# Out:
# target      127743
# protocol    127293
# dev         113420
# inode       113420
# fd           70595
# dirfd        90972
# ruid        127740
# euid        127740
# rgid        127733
# egid        127733
# sockfd      127153
# count       126959
# tls         127552
# arg2        127333
# arg3        127333
# arg4        127333
# arg5        127333
# pid         127552
# sig         127552
# oldfd       127601
# newfd       127612
# uid         127737
# gid         127741
# dtype: int64
